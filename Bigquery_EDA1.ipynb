# %%
pip install google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in ./anaconda3/lib/python3.7/site-packages (1.21.0)
# Requirement already satisfied: google-cloud-core<2.0dev,>=1.0.3 in ./anaconda3/lib/python3.7/site-packages (from google-cloud-bigquery) (1.0.3)
# Requirement already satisfied: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in ./anaconda3/lib/python3.7/site-packages (from google-cloud-bigquery) (0.4.1)
# Requirement already satisfied: protobuf>=3.6.0 in ./anaconda3/lib/python3.7/site-packages (from google-cloud-bigquery) (3.10.0)
# Requirement already satisfied: google-api-core<2.0.0dev,>=1.14.0 in ./anaconda3/lib/python3.7/site-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.14.3)
# Requirement already satisfied: six in ./anaconda3/lib/python3.7/site-packages (from google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1->google-cloud-bigquery) (1.12.0)
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.0->google-cloud-bigquery) (41.0.1)
# Requirement already satisfied: google-auth<2.0dev,>=0.4.0 in ./anaconda3/lib/python3.7/site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.6.3)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in ./anaconda3/lib/python3.7/site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.22.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in ./anaconda3/lib/python3.7/site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.6.0)
# Requirement already satisfied: pytz in ./anaconda3/lib/python3.7/site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2019.1)
# Requirement already satisfied: cachetools>=2.0.0 in ./anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.2.7)
# Requirement already satisfied: rsa>=3.1.4 in ./anaconda3/lib/python3.7/site-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in ./anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (2019.6.16)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./anaconda3/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (1.24.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./anaconda3/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery) (0.4.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] ='/Users/mastermind/Downloads/My First Project-aeea8b3a1dfd.json'

# %%
from google.cloud import bigquery

# %%
client = bigquery.Client()

# %%
dataset_ref = client.dataset("london_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)

# %%
# List all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there are four!)
for table in tables:  
    print(table.table_id)
# Out:
# crime_by_lsoa

# %%
# Construct a reference to the "full" table
table_ref = dataset_ref.table("crime_by_lsoa")

# API request - fetch the table
table = client.get_table(table_ref)

# %%
# Print information on all the columns in the "full" table in the "hacker_news" dataset
table.schema
# Out:
# [SchemaField('lsoa_code', 'STRING', 'NULLABLE', 'Lower Layer Super Output Area code according to the Office for National Statistics', ()),
#  SchemaField('borough', 'STRING', 'NULLABLE', '', ()),
#  SchemaField('major_category', 'STRING', 'NULLABLE', '', ()),
#  SchemaField('minor_category', 'STRING', 'NULLABLE', '', ()),
#  SchemaField('value', 'INTEGER', 'NULLABLE', 'Summary of the number of crimes for the month', ()),
#  SchemaField('year', 'INTEGER', 'NULLABLE', '', ()),
#  SchemaField('month', 'INTEGER', 'NULLABLE', '', ())]

# %%
bigquery_client = bigquery.Client()

# %%
QUERY = """
select * 
from `bigquery-public-data.london_crime.crime_by_lsoa`
limit 1000;
"""

# %%
query_job = bigquery_client.query(QUERY)

# %%
df = query_job.to_dataframe()

# %%
df
# Out:
#      lsoa_code         borough               major_category  \
# 0    E01000002  City of London  Violence Against the Person
# 1    E01000005  City of London  Violence Against the Person
# 2    E01000001  City of London  Violence Against the Person
# 3    E01032739  City of London  Violence Against the Person
# 4    E01000001  City of London  Violence Against the Person
# 5    E01000002  City of London  Violence Against the Person
# 6    E01032739  City of London  Violence Against the Person
# 7    E01032739  City of London  Violence Against the Person
# 8    E01000005  City of London  Violence Against the Person
# 9    E01032739  City of London  Violence Against the Person
# 10   E01000001  City of London  Violence Against the Person
# 11   E01000002  City of London  Violence Against the Person
# 12   E01032740  City of London  Violence Against the Person
# 13   E01000001  City of London  Violence Against the Person
# 14   E01000001  City of London  Violence Against the Person
# 15   E01000001  City of London  Violence Against the Person
# 16   E01000005  City of London  Violence Against the Person
# 17   E01000001  City of London  Violence Against the Person
# 18   E01000001  City of London  Violence Against the Person
# 19   E01000005  City of London  Violence Against the Person
# 20   E01000001  City of London  Violence Against the Person
# 21   E01032740  City of London  Violence Against the Person
# 22   E01000002  City of London  Violence Against the Person
# 23   E01032739  City of London  Violence Against the Person
# 24   E01032739  City of London  Violence Against the Person
# 25   E01000002  City of London  Violence Against the Person
# 26   E01000005  City of London  Violence Against the Person
# 27   E01032739  City of London  Violence Against the Person
# 28   E01032740  City of London  Violence Against the Person
# 29   E01032740  City of London  Violence Against the Person
# ..         ...             ...                          ...
# 970  E01000005  City of London              Criminal Damage
# 971  E01032739  City of London              Criminal Damage
# 972  E01000001  City of London              Criminal Damage
# 973  E01000005  City of London              Criminal Damage
# 974  E01000001  City of London              Criminal Damage
# 975  E01032740  City of London              Criminal Damage
# 976  E01032740  City of London              Criminal Damage
# 977  E01032740  City of London              Criminal Damage
# 978  E01032739  City of London              Criminal Damage
# 979  E01000001  City of London              Criminal Damage
# 980  E01000001  City of London              Criminal Damage
# 981  E01032740  City of London              Criminal Damage
# 982  E01032739  City of London              Criminal Damage
# 983  E01032740  City of London              Criminal Damage
# 984  E01000001  City of London              Criminal Damage
# 985  E01000005  City of London              Criminal Damage
# 986  E01032739  City of London              Criminal Damage
# 987  E01000005  City of London              Criminal Damage
# 988  E01000005  City of London              Criminal Damage
# 989  E01032740  City of London              Criminal Damage
# 990  E01000005  City of London           Theft and Handling
# 991  E01000003  City of London           Theft and Handling
# 992  E01000001  City of London           Theft and Handling
# 993  E01032739  City of London           Theft and Handling
# 994  E01000002  City of London           Theft and Handling
# 995  E01000005  City of London           Theft and Handling
# 996  E01032740  City of London           Theft and Handling
# 997  E01032740  City of London           Theft and Handling
# 998  E01000003  City of London           Theft and Handling
# 999  E01032739  City of London           Theft and Handling
#
#                minor_category  value  year  month
# 0                  Harassment      0  2011      9
# 1                  Harassment      0  2014      7
# 2                  Harassment      0  2008      3
# 3                  Harassment      0  2016      3
# 4                  Harassment      0  2011     10
# 5                  Harassment      0  2011      3
# 6                  Harassment      0  2009      9
# 7                  Harassment      0  2008      8
# 8                  Harassment      0  2016      5
# 9                  Harassment      0  2012     12
# 10                 Harassment      0  2010     10
# 11                 Harassment      0  2009      9
# 12                 Harassment      0  2010     10
# 13                 Harassment      0  2013     10
# 14                 Harassment      0  2015      2
# 15                 Harassment      0  2010      5
# 16                 Harassment      1  2013      7
# 17                 Harassment      0  2012      3
# 18                 Harassment      0  2010      9
# 19                 Harassment      0  2015      7
# 20                 Harassment      0  2011     12
# 21                 Harassment      0  2016      2
# 22                 Harassment      0  2010     12
# 23                 Harassment      0  2014      8
# 24                 Harassment      0  2011      7
# 25                 Harassment      0  2016      6
# 26                 Harassment      0  2014      8
# 27                 Harassment      0  2012      4
# 28                 Harassment      0  2014      5
# 29                 Harassment      0  2014     10
# ..                        ...    ...   ...    ...
# 970     Other Criminal Damage      0  2016      1
# 971     Other Criminal Damage      0  2013      7
# 972     Other Criminal Damage      0  2016      4
# 973     Other Criminal Damage      0  2008      7
# 974     Other Criminal Damage      0  2016      2
# 975     Other Criminal Damage      0  2016      3
# 976     Other Criminal Damage      0  2010      9
# 977     Other Criminal Damage      0  2010      8
# 978     Other Criminal Damage      0  2010      2
# 979     Other Criminal Damage      0  2009      8
# 980     Other Criminal Damage      0  2016     12
# 981     Other Criminal Damage      0  2015      5
# 982     Other Criminal Damage      0  2012      4
# 983     Other Criminal Damage      0  2012      5
# 984     Other Criminal Damage      0  2014      5
# 985     Other Criminal Damage      0  2016      3
# 986     Other Criminal Damage      0  2015     12
# 987     Other Criminal Damage      0  2014     10
# 988     Other Criminal Damage      0  2010      4
# 989     Other Criminal Damage      0  2009      4
# 990  Theft From Motor Vehicle      0  2011     12
# 991  Theft From Motor Vehicle      0  2016      4
# 992  Theft From Motor Vehicle      0  2009      4
# 993  Theft From Motor Vehicle      0  2010      4
# 994  Theft From Motor Vehicle      0  2011      3
# 995  Theft From Motor Vehicle      0  2016      9
# 996  Theft From Motor Vehicle      0  2009      7
# 997  Theft From Motor Vehicle      0  2010      2
# 998  Theft From Motor Vehicle      0  2010      9
# 999  Theft From Motor Vehicle      0  2015      8
#
# [1000 rows x 7 columns]

# %%
QUERY = """
select major_category, minor_category, year, sum(value) as value 
from `bigquery-public-data.london_crime.crime_by_lsoa`
group by major_category, minor_category, year
order by year, major_category, minor_category;
"""

# %%
query_job = bigquery_client.query(QUERY)

# %%
df1 = query_job.to_dataframe()

# %%
df1
# Out:
#                   major_category                          minor_category  \
# 0                       Burglary             Burglary in Other Buildings
# 1                       Burglary                  Burglary in a Dwelling
# 2                Criminal Damage             Criminal Damage To Dwelling
# 3                Criminal Damage        Criminal Damage To Motor Vehicle
# 4                Criminal Damage       Criminal Damage To Other Building
# 5                Criminal Damage                   Other Criminal Damage
# 6                          Drugs                        Drug Trafficking
# 7                          Drugs                             Other Drugs
# 8                          Drugs                     Possession Of Drugs
# 9               Fraud or Forgery                      Counted per Victim
# 10              Fraud or Forgery                   Other Fraud & Forgery
# 11     Other Notifiable Offences                          Going Equipped
# 12     Other Notifiable Offences                        Other Notifiable
# 13                       Robbery                       Business Property
# 14                       Robbery                       Personal Property
# 15               Sexual Offences                            Other Sexual
# 16               Sexual Offences                                    Rape
# 17            Theft and Handling                   Handling Stolen Goods
# 18            Theft and Handling  Motor Vehicle Interference & Tampering
# 19            Theft and Handling                             Other Theft
# 20            Theft and Handling                      Other Theft Person
# 21            Theft and Handling                Theft From Motor Vehicle
# 22            Theft and Handling                        Theft From Shops
# 23            Theft and Handling           Theft/Taking Of Motor Vehicle
# 24            Theft and Handling             Theft/Taking of Pedal Cycle
# 25   Violence Against the Person                     Assault with Injury
# 26   Violence Against the Person                          Common Assault
# 27   Violence Against the Person                              Harassment
# 28   Violence Against the Person                                  Murder
# 29   Violence Against the Person                        Offensive Weapon
# ..                           ...                                     ...
# 258              Criminal Damage             Criminal Damage To Dwelling
# 259              Criminal Damage        Criminal Damage To Motor Vehicle
# 260              Criminal Damage       Criminal Damage To Other Building
# 261              Criminal Damage                   Other Criminal Damage
# 262                        Drugs                        Drug Trafficking
# 263                        Drugs                             Other Drugs
# 264                        Drugs                     Possession Of Drugs
# 265             Fraud or Forgery                      Counted per Victim
# 266             Fraud or Forgery                   Other Fraud & Forgery
# 267    Other Notifiable Offences                          Going Equipped
# 268    Other Notifiable Offences                        Other Notifiable
# 269                      Robbery                       Business Property
# 270                      Robbery                       Personal Property
# 271              Sexual Offences                            Other Sexual
# 272              Sexual Offences                                    Rape
# 273           Theft and Handling                   Handling Stolen Goods
# 274           Theft and Handling  Motor Vehicle Interference & Tampering
# 275           Theft and Handling                             Other Theft
# 276           Theft and Handling                      Other Theft Person
# 277           Theft and Handling                Theft From Motor Vehicle
# 278           Theft and Handling                        Theft From Shops
# 279           Theft and Handling           Theft/Taking Of Motor Vehicle
# 280           Theft and Handling             Theft/Taking of Pedal Cycle
# 281  Violence Against the Person                     Assault with Injury
# 282  Violence Against the Person                          Common Assault
# 283  Violence Against the Person                              Harassment
# 284  Violence Against the Person                                  Murder
# 285  Violence Against the Person                        Offensive Weapon
# 286  Violence Against the Person                          Other violence
# 287  Violence Against the Person                            Wounding/GBH
#
#      year   value
# 0    2008   31437
# 1    2008   56655
# 2    2008   23519
# 3    2008   41693
# 4    2008    9011
# 5    2008   17649
# 6    2008    4203
# 7    2008     373
# 8    2008   64228
# 9    2008    3840
# 10   2008    1485
# 11   2008     621
# 12   2008    9491
# 13   2008    2964
# 14   2008   26663
# 15   2008    1005
# 16   2008     268
# 17   2008    2466
# 18   2008    3868
# 19   2008   99280
# 20   2008   24453
# 21   2008   76570
# 22   2008   32857
# 23   2008   28303
# 24   2008   15895
# 25   2008   56586
# 26   2008   37356
# 27   2008   43389
# 28   2008     130
# 29   2008    5961
# ..    ...     ...
# 258  2016   13951
# 259  2016   25787
# 260  2016    6700
# 261  2016   17633
# 262  2016    3392
# 263  2016     319
# 264  2016   35203
# 265  2016       0
# 266  2016       0
# 267  2016     604
# 268  2016   15205
# 269  2016    1654
# 270  2016   20874
# 271  2016       0
# 272  2016       0
# 273  2016    1377
# 274  2016   11438
# 275  2016  103807
# 276  2016   34868
# 277  2016   51319
# 278  2016   46957
# 279  2016   26366
# 280  2016   18001
# 281  2016   50038
# 282  2016   64440
# 283  2016   78676
# 284  2016     101
# 285  2016    5013
# 286  2016   10588
# 287  2016   23525
#
# [288 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(df1['major_category'], df1['value'])
# Out:
# <BarContainer object of 288 artists>

# %%
df1.columns = ['group', 'name', 'year', 'value']
dff = df1
dff
# Out:
#                            group                                    name  \
# 0                       Burglary             Burglary in Other Buildings
# 1                       Burglary                  Burglary in a Dwelling
# 2                Criminal Damage             Criminal Damage To Dwelling
# 3                Criminal Damage        Criminal Damage To Motor Vehicle
# 4                Criminal Damage       Criminal Damage To Other Building
# 5                Criminal Damage                   Other Criminal Damage
# 6                          Drugs                        Drug Trafficking
# 7                          Drugs                             Other Drugs
# 8                          Drugs                     Possession Of Drugs
# 9               Fraud or Forgery                      Counted per Victim
# 10              Fraud or Forgery                   Other Fraud & Forgery
# 11     Other Notifiable Offences                          Going Equipped
# 12     Other Notifiable Offences                        Other Notifiable
# 13                       Robbery                       Business Property
# 14                       Robbery                       Personal Property
# 15               Sexual Offences                            Other Sexual
# 16               Sexual Offences                                    Rape
# 17            Theft and Handling                   Handling Stolen Goods
# 18            Theft and Handling  Motor Vehicle Interference & Tampering
# 19            Theft and Handling                             Other Theft
# 20            Theft and Handling                      Other Theft Person
# 21            Theft and Handling                Theft From Motor Vehicle
# 22            Theft and Handling                        Theft From Shops
# 23            Theft and Handling           Theft/Taking Of Motor Vehicle
# 24            Theft and Handling             Theft/Taking of Pedal Cycle
# 25   Violence Against the Person                     Assault with Injury
# 26   Violence Against the Person                          Common Assault
# 27   Violence Against the Person                              Harassment
# 28   Violence Against the Person                                  Murder
# 29   Violence Against the Person                        Offensive Weapon
# ..                           ...                                     ...
# 258              Criminal Damage             Criminal Damage To Dwelling
# 259              Criminal Damage        Criminal Damage To Motor Vehicle
# 260              Criminal Damage       Criminal Damage To Other Building
# 261              Criminal Damage                   Other Criminal Damage
# 262                        Drugs                        Drug Trafficking
# 263                        Drugs                             Other Drugs
# 264                        Drugs                     Possession Of Drugs
# 265             Fraud or Forgery                      Counted per Victim
# 266             Fraud or Forgery                   Other Fraud & Forgery
# 267    Other Notifiable Offences                          Going Equipped
# 268    Other Notifiable Offences                        Other Notifiable
# 269                      Robbery                       Business Property
# 270                      Robbery                       Personal Property
# 271              Sexual Offences                            Other Sexual
# 272              Sexual Offences                                    Rape
# 273           Theft and Handling                   Handling Stolen Goods
# 274           Theft and Handling  Motor Vehicle Interference & Tampering
# 275           Theft and Handling                             Other Theft
# 276           Theft and Handling                      Other Theft Person
# 277           Theft and Handling                Theft From Motor Vehicle
# 278           Theft and Handling                        Theft From Shops
# 279           Theft and Handling           Theft/Taking Of Motor Vehicle
# 280           Theft and Handling             Theft/Taking of Pedal Cycle
# 281  Violence Against the Person                     Assault with Injury
# 282  Violence Against the Person                          Common Assault
# 283  Violence Against the Person                              Harassment
# 284  Violence Against the Person                                  Murder
# 285  Violence Against the Person                        Offensive Weapon
# 286  Violence Against the Person                          Other violence
# 287  Violence Against the Person                            Wounding/GBH
#
#      year   value
# 0    2008   31437
# 1    2008   56655
# 2    2008   23519
# 3    2008   41693
# 4    2008    9011
# 5    2008   17649
# 6    2008    4203
# 7    2008     373
# 8    2008   64228
# 9    2008    3840
# 10   2008    1485
# 11   2008     621
# 12   2008    9491
# 13   2008    2964
# 14   2008   26663
# 15   2008    1005
# 16   2008     268
# 17   2008    2466
# 18   2008    3868
# 19   2008   99280
# 20   2008   24453
# 21   2008   76570
# 22   2008   32857
# 23   2008   28303
# 24   2008   15895
# 25   2008   56586
# 26   2008   37356
# 27   2008   43389
# 28   2008     130
# 29   2008    5961
# ..    ...     ...
# 258  2016   13951
# 259  2016   25787
# 260  2016    6700
# 261  2016   17633
# 262  2016    3392
# 263  2016     319
# 264  2016   35203
# 265  2016       0
# 266  2016       0
# 267  2016     604
# 268  2016   15205
# 269  2016    1654
# 270  2016   20874
# 271  2016       0
# 272  2016       0
# 273  2016    1377
# 274  2016   11438
# 275  2016  103807
# 276  2016   34868
# 277  2016   51319
# 278  2016   46957
# 279  2016   26366
# 280  2016   18001
# 281  2016   50038
# 282  2016   64440
# 283  2016   78676
# 284  2016     101
# 285  2016    5013
# 286  2016   10588
# 287  2016   23525
#
# [288 rows x 4 columns]

# %%
current_year = 2016
dff = df1[df['year'].eq(current_year)].sort_values(by='value', ascending=True).head(10)
dff
# Out:
# /Users/mastermind/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                            group                               name  year  \
# 266             Fraud or Forgery              Other Fraud & Forgery  2016
# 239              Sexual Offences                       Other Sexual  2015
# 235    Other Notifiable Offences                     Going Equipped  2015
# 171    Other Notifiable Offences                     Going Equipped  2013
# 109                      Robbery                  Business Property  2011
# 45                       Robbery                  Business Property  2009
# 189  Violence Against the Person                   Offensive Weapon  2013
# 125  Violence Against the Person                   Offensive Weapon  2011
# 100              Criminal Damage  Criminal Damage To Other Building  2011
# 190  Violence Against the Person                     Other violence  2013
#
#      value
# 266      0
# 239      0
# 235    566
# 171    579
# 109   2685
# 45    3115
# 189   3315
# 125   3991
# 100   7445
# 190   7628

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(dff['name'], dff['value'])
# Out:
# <BarContainer object of 10 artists>

# %%
df=dff
df
# Out:
#                            group                                    name  \
# 0                       Burglary             Burglary in Other Buildings
# 1                       Burglary                  Burglary in a Dwelling
# 2                Criminal Damage             Criminal Damage To Dwelling
# 3                Criminal Damage        Criminal Damage To Motor Vehicle
# 4                Criminal Damage       Criminal Damage To Other Building
# 5                Criminal Damage                   Other Criminal Damage
# 6                          Drugs                        Drug Trafficking
# 7                          Drugs                             Other Drugs
# 8                          Drugs                     Possession Of Drugs
# 9               Fraud or Forgery                      Counted per Victim
# 10              Fraud or Forgery                   Other Fraud & Forgery
# 11     Other Notifiable Offences                          Going Equipped
# 12     Other Notifiable Offences                        Other Notifiable
# 13                       Robbery                       Business Property
# 14                       Robbery                       Personal Property
# 15               Sexual Offences                            Other Sexual
# 16               Sexual Offences                                    Rape
# 17            Theft and Handling                   Handling Stolen Goods
# 18            Theft and Handling  Motor Vehicle Interference & Tampering
# 19            Theft and Handling                             Other Theft
# 20            Theft and Handling                      Other Theft Person
# 21            Theft and Handling                Theft From Motor Vehicle
# 22            Theft and Handling                        Theft From Shops
# 23            Theft and Handling           Theft/Taking Of Motor Vehicle
# 24            Theft and Handling             Theft/Taking of Pedal Cycle
# 25   Violence Against the Person                     Assault with Injury
# 26   Violence Against the Person                          Common Assault
# 27   Violence Against the Person                              Harassment
# 28   Violence Against the Person                                  Murder
# 29   Violence Against the Person                        Offensive Weapon
# ..                           ...                                     ...
# 258              Criminal Damage             Criminal Damage To Dwelling
# 259              Criminal Damage        Criminal Damage To Motor Vehicle
# 260              Criminal Damage       Criminal Damage To Other Building
# 261              Criminal Damage                   Other Criminal Damage
# 262                        Drugs                        Drug Trafficking
# 263                        Drugs                             Other Drugs
# 264                        Drugs                     Possession Of Drugs
# 265             Fraud or Forgery                      Counted per Victim
# 266             Fraud or Forgery                   Other Fraud & Forgery
# 267    Other Notifiable Offences                          Going Equipped
# 268    Other Notifiable Offences                        Other Notifiable
# 269                      Robbery                       Business Property
# 270                      Robbery                       Personal Property
# 271              Sexual Offences                            Other Sexual
# 272              Sexual Offences                                    Rape
# 273           Theft and Handling                   Handling Stolen Goods
# 274           Theft and Handling  Motor Vehicle Interference & Tampering
# 275           Theft and Handling                             Other Theft
# 276           Theft and Handling                      Other Theft Person
# 277           Theft and Handling                Theft From Motor Vehicle
# 278           Theft and Handling                        Theft From Shops
# 279           Theft and Handling           Theft/Taking Of Motor Vehicle
# 280           Theft and Handling             Theft/Taking of Pedal Cycle
# 281  Violence Against the Person                     Assault with Injury
# 282  Violence Against the Person                          Common Assault
# 283  Violence Against the Person                              Harassment
# 284  Violence Against the Person                                  Murder
# 285  Violence Against the Person                        Offensive Weapon
# 286  Violence Against the Person                          Other violence
# 287  Violence Against the Person                            Wounding/GBH
#
#      year   value
# 0    2008   31437
# 1    2008   56655
# 2    2008   23519
# 3    2008   41693
# 4    2008    9011
# 5    2008   17649
# 6    2008    4203
# 7    2008     373
# 8    2008   64228
# 9    2008    3840
# 10   2008    1485
# 11   2008     621
# 12   2008    9491
# 13   2008    2964
# 14   2008   26663
# 15   2008    1005
# 16   2008     268
# 17   2008    2466
# 18   2008    3868
# 19   2008   99280
# 20   2008   24453
# 21   2008   76570
# 22   2008   32857
# 23   2008   28303
# 24   2008   15895
# 25   2008   56586
# 26   2008   37356
# 27   2008   43389
# 28   2008     130
# 29   2008    5961
# ..    ...     ...
# 258  2016   13951
# 259  2016   25787
# 260  2016    6700
# 261  2016   17633
# 262  2016    3392
# 263  2016     319
# 264  2016   35203
# 265  2016       0
# 266  2016       0
# 267  2016     604
# 268  2016   15205
# 269  2016    1654
# 270  2016   20874
# 271  2016       0
# 272  2016       0
# 273  2016    1377
# 274  2016   11438
# 275  2016  103807
# 276  2016   34868
# 277  2016   51319
# 278  2016   46957
# 279  2016   26366
# 280  2016   18001
# 281  2016   50038
# 282  2016   64440
# 283  2016   78676
# 284  2016     101
# 285  2016    5013
# 286  2016   10588
# 287  2016   23525
#
# [288 rows x 4 columns]

# %%
colors = dict(zip(
    ["Violence Against the Person", "Theft and Handling", "Sexual Offences", "Robbery", "Other Notifiable Offences", "Fraud or Forgery", "Drugs", 'Criminal Damage', 'Burglary'],
    ["#66ff66", "#ccffcc", "#ffff99", "#ffcc00", "#ff9900", "#00ff99", "#33cccc", "#0099ff", "#99ccff"]
))
group_lk = df.set_index('name')['group'].to_dict()

# %%
fig, ax = plt.subplots(figsize=(15, 8))

def draw_barchart(year):
    dff = df[df1['year'].eq(year)].sort_values(by='value', ascending=True).tail(10)
    ax.clear()
    ax.barh(dff['name'], dff['value'], color=[colors[group_lk[x]] for x in dff['name']])
    dx = dff['value'].max() / 200
    for i, (value, name) in enumerate(zip(dff['value'], dff['name'])):
        ax.text(value-dx, i,     name,           size=14, weight=600, ha='right', va='bottom')
        ax.text(value-dx, i-.25, group_lk[name], size=10, color='#444444', ha='right', va='baseline')
        ax.text(value+dx, i,     f'{value:,.0f}',  size=14, ha='left',  va='center')
    # ... polished styles
    ax.text(1, 0.4, year, transform=ax.transAxes, color='#777777', size=46, ha='right', weight=800)
    ax.text(0, 1.06, 'Recorded Cases', transform=ax.transAxes, size=12, color='#777777')
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
    ax.xaxis.set_ticks_position('top')
    ax.tick_params(axis='x', colors='#777777', labelsize=12)
    ax.set_yticks([])
    ax.margins(0, 0.01)
    ax.grid(which='major', axis='x', linestyle='-')
    ax.set_axisbelow(True)
    ax.text(0, 1.12, 'London Crimes 2008-2016',
            transform=ax.transAxes, size=24, weight=600, ha='left')
    ax.text(1, 0, 'by @viraj; credit @dhwanil', transform=ax.transAxes, ha='right',
            color='#777777', bbox=dict(facecolor='white', alpha=0.8, edgecolor='white'))
    plt.box(False)
    
draw_barchart(2016)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
animator = animation.FuncAnimation(fig, draw_barchart, frames=range(2008, 2016))
HTML(animator.to_jshtml())
# or use animator.to_html5_video() or animator.save()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img4adbabdb5a8b4ed7bd7a68c15372a510">
#   <div class="anim-controls">
#     <input id="_anim_slider4adbabdb5a8b4ed7bd7a68c15372a510" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim4adbabdb5a8b4ed7bd7a68c15372a510.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim4adbabdb5a8b4ed7bd7a68c15372a510.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select4adbabdb5a8b4ed7bd7a68c15372a510" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_4adbabdb5a8b4ed7bd7a68c15372a510"
#              >
#       <label for="_anim_radio1_4adbabdb5a8b4ed7bd7a68c15372a510">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_4adbabdb5a8b4ed7bd7a68c15372a510"
#              checked>
#       <label for="_anim_radio2_4adbabdb5a8b4ed7bd7a68c15372a510">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_4adbabdb5a8b4ed7bd7a68c15372a510"
#              >
#       <label for="_anim_radio3_4adbabdb5a8b4ed7bd7a68c15372a510">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img4adbabdb5a8b4ed7bd7a68c15372a510";
#     var slider_id = "_anim_slider4adbabdb5a8b4ed7bd7a68c15372a510";
#     var loop_select_id = "_anim_loop_select4adbabdb5a8b4ed7bd7a68c15372a510";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAAgAElEQVR4nOzdd1gU1/4/8Pc2epMqCiIiNqyAShSj\
# EXs3qMHYc23RWL5JNMbEaBI15sbEqDdqEguWXGyoiJ2oGIxdYwFRUVSkiFKliMDu/P7gx4TZXZri\
# FeL79Tz7ZOe0OTM7bnY+nHMGAlE5OnfuLAAQX507d37VXapyd+/elRwjAOHu3buvulsv5Pr164KP\
# j4/Ocel7mZqaCklJSc+9r/nz5//jr5EXERwcXKHPQSaTCZ988kmp7ajVamHChAlltmFpaSmEhoaW\
# 2sbt27eFRo0aldlG+/bthcePH+utf+nSJcHR0bHcYzE0NBQ2bdr03Oesf//+FTpnDg4Owh9//PHS\
# jlf72tZ+ubi4VOh4srOzhSFDhpR7PD179nye00VEREREgiDIQUT/OEeOHEHbtm1x5syZCpXPyclB\
# Xl7ec+9v5syZuHv3rvjaunXrc7f

# %%
QUERY = """
select major_category, year, sum(value) as value 
from `bigquery-public-data.london_crime.crime_by_lsoa`
group by major_category, year
order by year, major_category;
"""
query_job = bigquery_client.query(QUERY)
df2 = query_job.to_dataframe()

# %%
df2
# Out:
#                  major_category  year   value
# 0                      Burglary  2008   88092
# 1               Criminal Damage  2008   91872
# 2                         Drugs  2008   68804
# 3              Fraud or Forgery  2008    5325
# 4     Other Notifiable Offences  2008   10112
# 5                       Robbery  2008   29627
# 6               Sexual Offences  2008    1273
# 7            Theft and Handling  2008  283692
# 8   Violence Against the Person  2008  159844
# 9                      Burglary  2009   90619
# 10              Criminal Damage  2009   85565
# 11                        Drugs  2009   60549
# 12             Fraud or Forgery  2009       0
# 13    Other Notifiable Offences  2009   10644
# 14                      Robbery  2009   29568
# 15              Sexual Offences  2009       0
# 16           Theft and Handling  2009  279492
# 17  Violence Against the Person  2009  160777
# 18                     Burglary  2010   86826
# 19              Criminal Damage  2010   77897
# 20                        Drugs  2010   58674
# 21             Fraud or Forgery  2010       0
# 22    Other Notifiable Offences  2010   10768
# 23                      Robbery  2010   32341
# 24              Sexual Offences  2010       0
# 25           Theft and Handling  2010  290924
# 26  Violence Against the Person  2010  157894
# 27                     Burglary  2011   93315
# 28              Criminal Damage  2011   70914
# 29                        Drugs  2011   57550
# ..                          ...   ...     ...
# 51              Sexual Offences  2013       0
# 52           Theft and Handling  2013  306372
# 53  Violence Against the Person  2013  146181
# 54                     Burglary  2014   76053
# 55              Criminal Damage  2014   59279
# 56                        Drugs  2014   44435
# 57             Fraud or Forgery  2014       0
# 58    Other Notifiable Offences  2014   13037
# 59                      Robbery  2014   22150
# 60              Sexual Offences  2014       0
# 61           Theft and Handling  2014  279880
# 62  Violence Against the Person  2014  185349
# 63                     Burglary  2015   70489
# 64              Criminal Damage  2015   62976
# 65                        Drugs  2015   39785
# 66             Fraud or Forgery  2015       0
# 67    Other Notifiable Offences  2015   14229
# 68                      Robbery  2015   21383
# 69              Sexual Offences  2015       0
# 70           Theft and Handling  2015  284022
# 71  Violence Against the Person  2015  218740
# 72                     Burglary  2016   68285
# 73              Criminal Damage  2016   64071
# 74                        Drugs  2016   38914
# 75             Fraud or Forgery  2016       0
# 76    Other Notifiable Offences  2016   15809
# 77                      Robbery  2016   22528
# 78              Sexual Offences  2016       0
# 79           Theft and Handling  2016  294133
# 80  Violence Against the Person  2016  232381
#
# [81 rows x 3 columns]

# %%
df2.columns = ['a', 'b', 'Quantity']

# %%
import pandas as pd
import plotly
import plotly.plotly as py

def genSankey(df,cat_cols=[],value_cols='',title='Sankey Diagram'):
    # maximum of 6 value cols -> 6 colors
    colorPalette = ['#FFD43B','#646464','#4B8BBE','#306998']
    labelList = []
    colorNumList = []
    for catCol in cat_cols:
        labelListTemp =  list(set(df[catCol].values))
        colorNumList.append(len(labelListTemp))
        labelList = labelList + labelListTemp
        
    # remove duplicates from labelList
    labelList = list(dict.fromkeys(labelList))
    
    # define colors based on number of levels
    colorList = []
    for idx, colorNum in enumerate(colorNumList):
        colorList = colorList + [colorPalette[idx]]*colorNum
        
    # transform df into a source-target pair
    for i in range(len(cat_cols)-1):
        if i==0:
            sourceTargetDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            sourceTargetDf.columns = ['source','target','count']
        else:
            tempDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            tempDf.columns = ['source','target','count']
            sourceTargetDf = pd.concat([sourceTargetDf,tempDf])
        sourceTargetDf = sourceTargetDf.groupby(['source','target']).agg({'count':'sum'}).reset_index()
        
    # add index for source-target pair
    sourceTargetDf['sourceID'] = sourceTargetDf['source'].apply(lambda x: labelList.index(x))
    sourceTargetDf['targetID'] = sourceTargetDf['target'].apply(lambda x: labelList.index(x))
    
    # creating the sankey diagram
    data = dict(
        type='sankey',
        node = dict(
          pad = 15,
          thickness = 20,
          line = dict(
            color = "black",
            width = 0.5
          ),
          label = labelList,
          color = colorList
        ),
        link = dict(
          source = sourceTargetDf['sourceID'],
          target = sourceTargetDf['targetID'],
          value = sourceTargetDf['count']
        )
      )
    
    layout =  dict(
        title = title,
        font = dict(
          size = 10
        )
    )
       
    fig = dict(data=[data], layout=layout)
    return fig

#here we call the previously defined sankey function and we add our dataframe columns to the arguments
fig = genSankey(df2,cat_cols=['a','b'],value_cols='Quantity',title='Sankey Diagram x Profit')
plotly.offline.plot(fig, validate=False)
# Out:
# 'file:///Users/mastermind/temp-plot.html'

# %%
QUERY = """
select minor_category, year,sum(value) as total_possesions
from `bigquery-public-data.london_crime.crime_by_lsoa`
where major_category='Theft and Handling'
and year in (2008,2016)
group by 1,2
order by 2 desc
;
"""
query_job = bigquery_client.query(QUERY)
df3 = query_job.to_dataframe()

# %%
df3
# Out:
#                             minor_category  year  total_possesions
# 0                              Other Theft  2016            103807
# 1                         Theft From Shops  2016             46957
# 2                       Other Theft Person  2016             34868
# 3                    Handling Stolen Goods  2016              1377
# 4                 Theft From Motor Vehicle  2016             51319
# 5              Theft/Taking of Pedal Cycle  2016             18001
# 6            Theft/Taking Of Motor Vehicle  2016             26366
# 7   Motor Vehicle Interference & Tampering  2016             11438
# 8                              Other Theft  2008             99280
# 9                         Theft From Shops  2008             32857
# 10                      Other Theft Person  2008             24453
# 11                   Handling Stolen Goods  2008              2466
# 12                Theft From Motor Vehicle  2008             76570
# 13             Theft/Taking of Pedal Cycle  2008             15895
# 14           Theft/Taking Of Motor Vehicle  2008             28303
# 15  Motor Vehicle Interference & Tampering  2008              3868

# %%
df3.columns = ['a', 'b', 'Quantity']

# %%
import pandas as pd
import plotly
import plotly.plotly as py

def genSankey(df,cat_cols=[],value_cols='',title='Sankey Diagram'):
    # maximum of 6 value cols -> 6 colors
    colorPalette = ['#FFD43B','#646464','#4B8BBE','#306998']
    labelList = []
    colorNumList = []
    for catCol in cat_cols:
        labelListTemp =  list(set(df[catCol].values))
        colorNumList.append(len(labelListTemp))
        labelList = labelList + labelListTemp
        
    # remove duplicates from labelList
    labelList = list(dict.fromkeys(labelList))
    
    # define colors based on number of levels
    colorList = []
    for idx, colorNum in enumerate(colorNumList):
        colorList = colorList + [colorPalette[idx]]*colorNum
        
    # transform df into a source-target pair
    for i in range(len(cat_cols)-1):
        if i==0:
            sourceTargetDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            sourceTargetDf.columns = ['source','target','count']
        else:
            tempDf = df[[cat_cols[i],cat_cols[i+1],value_cols]]
            tempDf.columns = ['source','target','count']
            sourceTargetDf = pd.concat([sourceTargetDf,tempDf])
        sourceTargetDf = sourceTargetDf.groupby(['source','target']).agg({'count':'sum'}).reset_index()
        
    # add index for source-target pair
    sourceTargetDf['sourceID'] = sourceTargetDf['source'].apply(lambda x: labelList.index(x))
    sourceTargetDf['targetID'] = sourceTargetDf['target'].apply(lambda x: labelList.index(x))
    
    # creating the sankey diagram
    data = dict(
        type='sankey',
        node = dict(
          pad = 15,
          thickness = 20,
          line = dict(
            color = "black",
            width = 0.5
          ),
          label = labelList,
          color = colorList
        ),
        link = dict(
          source = sourceTargetDf['sourceID'],
          target = sourceTargetDf['targetID'],
          value = sourceTargetDf['count']
        )
      )
    
    layout =  dict(
        title = title,
        font = dict(
          size = 10
        )
    )
       
    fig = dict(data=[data], layout=layout)
    return fig

#here we call the previously defined sankey function and we add our dataframe columns to the arguments
fig = genSankey(df3,cat_cols=['a','b'],value_cols='Quantity',title='Sankey Diagram x Profit')
plotly.offline.plot(fig, validate=False)
# Out:
# 'file:///Users/mastermind/temp-plot.html'

# %%
QUERY = """
select major_category, minor_category, year,sum(value) as total_possesions
from `bigquery-public-data.london_crime.crime_by_lsoa`
where major_category='Theft and Handling'
group by 1,2,3
order by 3 desc
;
"""
query_job = bigquery_client.query(QUERY)
df4 = query_job.to_dataframe()

# %%
df4
# Out:
#         major_category                          minor_category  year  \
# 0   Theft and Handling                             Other Theft  2016
# 1   Theft and Handling                        Theft From Shops  2016
# 2   Theft and Handling                      Other Theft Person  2016
# 3   Theft and Handling                   Handling Stolen Goods  2016
# 4   Theft and Handling                Theft From Motor Vehicle  2016
# 5   Theft and Handling             Theft/Taking of Pedal Cycle  2016
# 6   Theft and Handling           Theft/Taking Of Motor Vehicle  2016
# 7   Theft and Handling  Motor Vehicle Interference & Tampering  2016
# 8   Theft and Handling                             Other Theft  2015
# 9   Theft and Handling                        Theft From Shops  2015
# 10  Theft and Handling                      Other Theft Person  2015
# 11  Theft and Handling                   Handling Stolen Goods  2015
# 12  Theft and Handling                Theft From Motor Vehicle  2015
# 13  Theft and Handling             Theft/Taking of Pedal Cycle  2015
# 14  Theft and Handling           Theft/Taking Of Motor Vehicle  2015
# 15  Theft and Handling  Motor Vehicle Interference & Tampering  2015
# 16  Theft and Handling                             Other Theft  2014
# 17  Theft and Handling                        Theft From Shops  2014
# 18  Theft and Handling                      Other Theft Person  2014
# 19  Theft and Handling                   Handling Stolen Goods  2014
# 20  Theft and Handling                Theft From Motor Vehicle  2014
# 21  Theft and Handling             Theft/Taking of Pedal Cycle  2014
# 22  Theft and Handling           Theft/Taking Of Motor Vehicle  2014
# 23  Theft and Handling  Motor Vehicle Interference & Tampering  2014
# 24  Theft and Handling                             Other Theft  2013
# 25  Theft and Handling                      Other Theft Person  2013
# 26  Theft and Handling                   Handling Stolen Goods  2013
# 27  Theft and Handling                Theft From Motor Vehicle  2013
# 28  Theft and Handling             Theft/Taking of Pedal Cycle  2013
# 29  Theft and Handling           Theft/Taking Of Motor Vehicle  2013
# ..                 ...                                     ...   ...
# 42  Theft and Handling                      Other Theft Person  2011
# 43  Theft and Handling                   Handling Stolen Goods  2011
# 44  Theft and Handling                Theft From Motor Vehicle  2011
# 45  Theft and Handling             Theft/Taking of Pedal Cycle  2011
# 46  Theft and Handling           Theft/Taking Of Motor Vehicle  2011
# 47  Theft and Handling  Motor Vehicle Interference & Tampering  2011
# 48  Theft and Handling                             Other Theft  2010
# 49  Theft and Handling                        Theft From Shops  2010
# 50  Theft and Handling                      Other Theft Person  2010
# 51  Theft and Handling                   Handling Stolen Goods  2010
# 52  Theft and Handling                Theft From Motor Vehicle  2010
# 53  Theft and Handling             Theft/Taking of Pedal Cycle  2010
# 54  Theft and Handling           Theft/Taking Of Motor Vehicle  2010
# 55  Theft and Handling  Motor Vehicle Interference & Tampering  2010
# 56  Theft and Handling                             Other Theft  2009
# 57  Theft and Handling                        Theft From Shops  2009
# 58  Theft and Handling                      Other Theft Person  2009
# 59  Theft and Handling                   Handling Stolen Goods  2009
# 60  Theft and Handling                Theft From Motor Vehicle  2009
# 61  Theft and Handling             Theft/Taking of Pedal Cycle  2009
# 62  Theft and Handling           Theft/Taking Of Motor Vehicle  2009
# 63  Theft and Handling  Motor Vehicle Interference & Tampering  2009
# 64  Theft and Handling                             Other Theft  2008
# 65  Theft and Handling                        Theft From Shops  2008
# 66  Theft and Handling                      Other Theft Person  2008
# 67  Theft and Handling                   Handling Stolen Goods  2008
# 68  Theft and Handling                Theft From Motor Vehicle  2008
# 69  Theft and Handling             Theft/Taking of Pedal Cycle  2008
# 70  Theft and Handling           Theft/Taking Of Motor Vehicle  2008
# 71  Theft and Handling  Motor Vehicle Interference & Tampering  2008
#
#     total_possesions
# 0             103807
# 1              46957
# 2              34868
# 3               1377
# 4              51319
# 5              18001
# 6              26366
# 7              11438
# 8             107571
# 9              42549
# 10             33829
# 11              1388
# 12             50024
# 13             16513
# 14             21848
# 15             10300
# 16            108577
# 17             40141
# 18             30957
# 19              1588
# 20             52167
# 21             17186
# 22             21653
# 23              7611
# 24            115757
# 25             44964
# 26              1819
# 27             63509
# 28             18708
# 29             20377
# ..               ...
# 42             36090
# 43              2104
# 44             69604
# 45             20885
# 46             26161
# 47              4481
# 48            103997
# 49             36935
# 50             29547
# 51              1714
# 52             69709
# 53             19726
# 54             24890
# 55              4406
# 56             95424
# 57             36349
# 58             27549
# 59              1907
# 60             68856
# 61             20721
# 62             24476
# 63              4210
# 64             99280
# 65             32857
# 66             24453
# 67              2466
# 68             76570
# 69             15895
# 70             28303
# 71              3868
#
# [72 rows x 4 columns]

# %%
df4.columns = ['group', 'name', 'year', 'value']
dff = df4
dff
# Out:
#                  group                                    name  year   value
# 0   Theft and Handling                             Other Theft  2016  103807
# 1   Theft and Handling                        Theft From Shops  2016   46957
# 2   Theft and Handling                      Other Theft Person  2016   34868
# 3   Theft and Handling                   Handling Stolen Goods  2016    1377
# 4   Theft and Handling                Theft From Motor Vehicle  2016   51319
# 5   Theft and Handling             Theft/Taking of Pedal Cycle  2016   18001
# 6   Theft and Handling           Theft/Taking Of Motor Vehicle  2016   26366
# 7   Theft and Handling  Motor Vehicle Interference & Tampering  2016   11438
# 8   Theft and Handling                             Other Theft  2015  107571
# 9   Theft and Handling                        Theft From Shops  2015   42549
# 10  Theft and Handling                      Other Theft Person  2015   33829
# 11  Theft and Handling                   Handling Stolen Goods  2015    1388
# 12  Theft and Handling                Theft From Motor Vehicle  2015   50024
# 13  Theft and Handling             Theft/Taking of Pedal Cycle  2015   16513
# 14  Theft and Handling           Theft/Taking Of Motor Vehicle  2015   21848
# 15  Theft and Handling  Motor Vehicle Interference & Tampering  2015   10300
# 16  Theft and Handling                             Other Theft  2014  108577
# 17  Theft and Handling                        Theft From Shops  2014   40141
# 18  Theft and Handling                      Other Theft Person  2014   30957
# 19  Theft and Handling                   Handling Stolen Goods  2014    1588
# 20  Theft and Handling                Theft From Motor Vehicle  2014   52167
# 21  Theft and Handling             Theft/Taking of Pedal Cycle  2014   17186
# 22  Theft and Handling           Theft/Taking Of Motor Vehicle  2014   21653
# 23  Theft and Handling  Motor Vehicle Interference & Tampering  2014    7611
# 24  Theft and Handling                             Other Theft  2013  115757
# 25  Theft and Handling                      Other Theft Person  2013   44964
# 26  Theft and Handling                   Handling Stolen Goods  2013    1819
# 27  Theft and Handling                Theft From Motor Vehicle  2013   63509
# 28  Theft and Handling             Theft/Taking of Pedal Cycle  2013   18708
# 29  Theft and Handling           Theft/Taking Of Motor Vehicle  2013   20377
# ..                 ...                                     ...   ...     ...
# 42  Theft and Handling                      Other Theft Person  2011   36090
# 43  Theft and Handling                   Handling Stolen Goods  2011    2104
# 44  Theft and Handling                Theft From Motor Vehicle  2011   69604
# 45  Theft and Handling             Theft/Taking of Pedal Cycle  2011   20885
# 46  Theft and Handling           Theft/Taking Of Motor Vehicle  2011   26161
# 47  Theft and Handling  Motor Vehicle Interference & Tampering  2011    4481
# 48  Theft and Handling                             Other Theft  2010  103997
# 49  Theft and Handling                        Theft From Shops  2010   36935
# 50  Theft and Handling                      Other Theft Person  2010   29547
# 51  Theft and Handling                   Handling Stolen Goods  2010    1714
# 52  Theft and Handling                Theft From Motor Vehicle  2010   69709
# 53  Theft and Handling             Theft/Taking of Pedal Cycle  2010   19726
# 54  Theft and Handling           Theft/Taking Of Motor Vehicle  2010   24890
# 55  Theft and Handling  Motor Vehicle Interference & Tampering  2010    4406
# 56  Theft and Handling                             Other Theft  2009   95424
# 57  Theft and Handling                        Theft From Shops  2009   36349
# 58  Theft and Handling                      Other Theft Person  2009   27549
# 59  Theft and Handling                   Handling Stolen Goods  2009    1907
# 60  Theft and Handling                Theft From Motor Vehicle  2009   68856
# 61  Theft and Handling             Theft/Taking of Pedal Cycle  2009   20721
# 62  Theft and Handling           Theft/Taking Of Motor Vehicle  2009   24476
# 63  Theft and Handling  Motor Vehicle Interference & Tampering  2009    4210
# 64  Theft and Handling                             Other Theft  2008   99280
# 65  Theft and Handling                        Theft From Shops  2008   32857
# 66  Theft and Handling                      Other Theft Person  2008   24453
# 67  Theft and Handling                   Handling Stolen Goods  2008    2466
# 68  Theft and Handling                Theft From Motor Vehicle  2008   76570
# 69  Theft and Handling             Theft/Taking of Pedal Cycle  2008   15895
# 70  Theft and Handling           Theft/Taking Of Motor Vehicle  2008   28303
# 71  Theft and Handling  Motor Vehicle Interference & Tampering  2008    3868
#
# [72 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(15, 8))
ax.barh(dff['name'], dff['value'])
# Out:
# <BarContainer object of 72 artists>

# %%
df=dff
df
# Out:
#                  group                                    name  year   value
# 0   Theft and Handling                             Other Theft  2016  103807
# 1   Theft and Handling                        Theft From Shops  2016   46957
# 2   Theft and Handling                      Other Theft Person  2016   34868
# 3   Theft and Handling                   Handling Stolen Goods  2016    1377
# 4   Theft and Handling                Theft From Motor Vehicle  2016   51319
# 5   Theft and Handling             Theft/Taking of Pedal Cycle  2016   18001
# 6   Theft and Handling           Theft/Taking Of Motor Vehicle  2016   26366
# 7   Theft and Handling  Motor Vehicle Interference & Tampering  2016   11438
# 8   Theft and Handling                             Other Theft  2015  107571
# 9   Theft and Handling                        Theft From Shops  2015   42549
# 10  Theft and Handling                      Other Theft Person  2015   33829
# 11  Theft and Handling                   Handling Stolen Goods  2015    1388
# 12  Theft and Handling                Theft From Motor Vehicle  2015   50024
# 13  Theft and Handling             Theft/Taking of Pedal Cycle  2015   16513
# 14  Theft and Handling           Theft/Taking Of Motor Vehicle  2015   21848
# 15  Theft and Handling  Motor Vehicle Interference & Tampering  2015   10300
# 16  Theft and Handling                             Other Theft  2014  108577
# 17  Theft and Handling                        Theft From Shops  2014   40141
# 18  Theft and Handling                      Other Theft Person  2014   30957
# 19  Theft and Handling                   Handling Stolen Goods  2014    1588
# 20  Theft and Handling                Theft From Motor Vehicle  2014   52167
# 21  Theft and Handling             Theft/Taking of Pedal Cycle  2014   17186
# 22  Theft and Handling           Theft/Taking Of Motor Vehicle  2014   21653
# 23  Theft and Handling  Motor Vehicle Interference & Tampering  2014    7611
# 24  Theft and Handling                             Other Theft  2013  115757
# 25  Theft and Handling                      Other Theft Person  2013   44964
# 26  Theft and Handling                   Handling Stolen Goods  2013    1819
# 27  Theft and Handling                Theft From Motor Vehicle  2013   63509
# 28  Theft and Handling             Theft/Taking of Pedal Cycle  2013   18708
# 29  Theft and Handling           Theft/Taking Of Motor Vehicle  2013   20377
# ..                 ...                                     ...   ...     ...
# 42  Theft and Handling                      Other Theft Person  2011   36090
# 43  Theft and Handling                   Handling Stolen Goods  2011    2104
# 44  Theft and Handling                Theft From Motor Vehicle  2011   69604
# 45  Theft and Handling             Theft/Taking of Pedal Cycle  2011   20885
# 46  Theft and Handling           Theft/Taking Of Motor Vehicle  2011   26161
# 47  Theft and Handling  Motor Vehicle Interference & Tampering  2011    4481
# 48  Theft and Handling                             Other Theft  2010  103997
# 49  Theft and Handling                        Theft From Shops  2010   36935
# 50  Theft and Handling                      Other Theft Person  2010   29547
# 51  Theft and Handling                   Handling Stolen Goods  2010    1714
# 52  Theft and Handling                Theft From Motor Vehicle  2010   69709
# 53  Theft and Handling             Theft/Taking of Pedal Cycle  2010   19726
# 54  Theft and Handling           Theft/Taking Of Motor Vehicle  2010   24890
# 55  Theft and Handling  Motor Vehicle Interference & Tampering  2010    4406
# 56  Theft and Handling                             Other Theft  2009   95424
# 57  Theft and Handling                        Theft From Shops  2009   36349
# 58  Theft and Handling                      Other Theft Person  2009   27549
# 59  Theft and Handling                   Handling Stolen Goods  2009    1907
# 60  Theft and Handling                Theft From Motor Vehicle  2009   68856
# 61  Theft and Handling             Theft/Taking of Pedal Cycle  2009   20721
# 62  Theft and Handling           Theft/Taking Of Motor Vehicle  2009   24476
# 63  Theft and Handling  Motor Vehicle Interference & Tampering  2009    4210
# 64  Theft and Handling                             Other Theft  2008   99280
# 65  Theft and Handling                        Theft From Shops  2008   32857
# 66  Theft and Handling                      Other Theft Person  2008   24453
# 67  Theft and Handling                   Handling Stolen Goods  2008    2466
# 68  Theft and Handling                Theft From Motor Vehicle  2008   76570
# 69  Theft and Handling             Theft/Taking of Pedal Cycle  2008   15895
# 70  Theft and Handling           Theft/Taking Of Motor Vehicle  2008   28303
# 71  Theft and Handling  Motor Vehicle Interference & Tampering  2008    3868
#
# [72 rows x 4 columns]

# %%
colors = dict(zip(
    ['Theft and Handling'],
    ["#66ff66"]
))
group_lk = df.set_index('name')['group'].to_dict()

# %%
fig, ax = plt.subplots(figsize=(15, 8))

def draw_barchart(year):
    dff = df[df['year'].eq(year)].sort_values(by='value', ascending=True).tail(10)
    ax.clear()
    ax.barh(dff['name'], dff['value'], color=[colors[group_lk[x]] for x in dff['name']])
    dx = dff['value'].max() / 200
    for i, (value, name) in enumerate(zip(dff['value'], dff['name'])):
        ax.text(value-dx, i,     name,           size=14, weight=600, ha='right', va='bottom')
        ax.text(value-dx, i-.25, group_lk[name], size=10, color='#444444', ha='right', va='baseline')
        ax.text(value+dx, i,     f'{value:,.0f}',  size=14, ha='left',  va='center')
    # ... polished styles
    ax.text(1, 0.4, year, transform=ax.transAxes, color='#777777', size=46, ha='right', weight=800)
    ax.text(0, 1.06, 'Recorded Cases', transform=ax.transAxes, size=12, color='#777777')
    ax.xaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
    ax.xaxis.set_ticks_position('top')
    ax.tick_params(axis='x', colors='#777777', labelsize=12)
    ax.set_yticks([])
    ax.margins(0, 0.01)
    ax.grid(which='major', axis='x', linestyle='-')
    ax.set_axisbelow(True)
    ax.text(0, 1.12, 'Cases of Theft and Handling Between 2008-2016',
            transform=ax.transAxes, size=24, weight=600, ha='left')
    ax.text(1, 0, 'by @viraj; credit @dhwanil', transform=ax.transAxes, ha='right',
            color='#777777', bbox=dict(facecolor='white', alpha=0.8, edgecolor='white'))
    plt.box(False)
    
draw_barchart(2016)

# %%
fig, ax = plt.subplots(figsize=(15, 8))
animator = animation.FuncAnimation(fig, draw_barchart, frames=range(2008, 2016))
HTML(animator.to_jshtml())
# or use animator.to_html5_video() or animator.save()
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7614c8d697d745ea85ae584053045c13">
#   <div class="anim-controls">
#     <input id="_anim_slider7614c8d697d745ea85ae584053045c13" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7614c8d697d745ea85ae584053045c13.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim7614c8d697d745ea85ae584053045c13.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select7614c8d697d745ea85ae584053045c13" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7614c8d697d745ea85ae584053045c13"
#              >
#       <label for="_anim_radio1_7614c8d697d745ea85ae584053045c13">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7614c8d697d745ea85ae584053045c13"
#              checked>
#       <label for="_anim_radio2_7614c8d697d745ea85ae584053045c13">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7614c8d697d745ea85ae584053045c13"
#              >
#       <label for="_anim_radio3_7614c8d697d745ea85ae584053045c13">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7614c8d697d745ea85ae584053045c13";
#     var slider_id = "_anim_slider7614c8d697d745ea85ae584053045c13";
#     var loop_select_id = "_anim_loop_select7614c8d697d745ea85ae584053045c13";
#     var frames = new Array(8);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjAsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+17YcXAAAgAElEQVR4nOzdd1gU1/4/8De77NJ7RxAQFbEXVGzB\
# KFgSO9ZYk2hMTNGbxHxTNHqT6DXXkhgTjYlGo4k12DD2ggULikFEELEXigKy0svu/P7gx1xmd1lA\
# MUB8v55nH3bnzDlzZnZ2mP3sKRCIqig+Pl4IDAwUAFT6sLCwEFJSUmq7yv94eXl5grm5eYXvg42N\
# TaVlBAUFVek9reixZs0aQRAEYc6cOZLlQUFBz3bnK/Drr78arO/06dMFQRCEo0eP6qQ9D2rifZo4\
# caKkDC8vrypvrz4f58qOXVXOKe30o0eP/j2Vfwaqe+149dVXBY1G80zq8k86rnVdq1atqvR++/r6\
# CvHx8RWWExUVJbi6uhosY8CAAUJeXl6FZcydO1eQy+UV5jcxMRF++uknvXk1Go3w1ltvVWlfunXr\
# JmRmZj7R8YqOjq7yZ2TChAlCcXH

# %%
Other Theft", "Theft From Shops", "Other Theft Person", "Handling Stolen Goods", "Theft From Motor Vehicle", "Theft/Taking of Pedal Cycle", "Theft/Taking Of Motor Vehicle", 'Motor Vehicle Interference & Tampering'
, "#ccffcc", "#ffff99", "#ffcc00", "#ff9900", "#00ff99", "#33cccc", "#0099ff"
